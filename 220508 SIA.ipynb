# %% [markdown]
# SIA Online Test

# %%
stocks = ['AMZN', 'CACC', 'EQIX', 'GOOG', 'ORLY', 'ULTA']
prices = [[12.81, 11.09, 12.11, 10.93, 9.83, 8.14], [10.34, 10.56, 10.14, 12.17, 13.1, 11.22], [11.53, 10.67, 10.42, 11.88, 11.77, 10.21]]

# %%
list[0]=
[stocks[0],prices[0][0]
 stocks[1],prices[0][1]
 stocks[2],prices[0][2]
 stocks[3],prices[0][3]
 stocks[4],prices[0][4]
 stocks[5],prices[0][5]]

# %%
import numpy as np

a=[]
c=[]
count=0
for i in range(len(prices)):
    M = np.mean(prices[i])
    for j in range(len(prices[i])-1):
        if (abs((prices[i][j])-M))>(abs((prices[i][j+1])-M)) :
            count+=1
    print(count)
    c.append(count)
print(c)
for k in c:
    print(stocks[k])
# Out:
# 2
# 5
# 7
# [2, 5, 7]
# EQIX
# ULTA
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-120-6fd84fb167ff> in <module>
#      13 print(c)
#      14 for k in c:
# ---> 15     print(stocks[k])
#
# IndexError: list index out of range

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(prices[i][j])
# Out:
# 11.77
